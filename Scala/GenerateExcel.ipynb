# %%
# %scala
import org.apache.spark.sql.Dataset

import spark.implicits._
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import org.apache.spark.sql.Dataset
# import spark.implicits._
# </div>

# %%
# %scala

val df1 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Orders_BMW.csv")
//df1.show()

val df2 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Orders_MotoRad.csv")
//df2.show()

val df3 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Orders_Mini.csv")
//df3.show()

val df4 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Sales_BMW.csv")
//df4.show()

val df5 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Sales_MotoRad.csv")
//df5.show()

val df6 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Sales_Mini.csv")
//df6.show()

val df7 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Stock_BMW.csv")
//df7.show()

val df8 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Stock_MotoRad.csv")
//df8.show()

val df9 = spark.read.option("header",true)
   .csv("/mnt/business/Inchcape/Chile/Autoline/Stock_Mini.csv")
df9.show()

df1.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Orders BMW'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")

df2.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Orders BMW Motorrad'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")

df3.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Orders MINI'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")

df4.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Sales BMW'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")

df5.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Sales BMW Motorrad'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")

df6.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Sales MINI'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")

df7.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Stocks BMW'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")

df8.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Stocks BMW Motorrad'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")

df9.write
.format("com.crealytics.spark.excel")
.option("dataAddress", "'Stocks MINI'!A1:Y1000000")
.option("header", "true")
.mode("append")
.save("/mnt/business/Inchcape/Chile/Autoline/Orders_Data.xlsx")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----------+------------+-------------+----------+--------+------------------+----------+
#    EOM|Master Key|Landed Stock|Manual Orders|Order Bank|Arrivals|Production Request|Allocation|
# +------+----------+------------+-------------+----------+--------+------------------+----------+
# 202107|  M3P15ATC|           0|            0|         2|       0|                 0|         0|
# 202108|  M3P15ATC|           1|            0|         2|       7|                 0|         0|
# 202109|  M3P15ATC|           0|            0|         0|       0|                 0|         0|
# ...
